# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Generative-model-specifications" data-toc-modified-id="Generative-model-specifications-0"><span class="toc-item-num">0&nbsp;&nbsp;</span>Generative model specifications</a></span><ul class="toc-item"><li><span><a href="#Model-prior" data-toc-modified-id="Model-prior-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Model prior</a></span></li><li><span><a href="#Model-parameters-priors" data-toc-modified-id="Model-parameters-priors-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Model parameters priors</a></span></li><li><span><a href="#Generative-models" data-toc-modified-id="Generative-models-0.3"><span class="toc-item-num">0.3&nbsp;&nbsp;</span>Generative models</a></span></li><li><span><a href="#Data-generator" data-toc-modified-id="Data-generator-0.4"><span class="toc-item-num">0.4&nbsp;&nbsp;</span>Data generator</a></span></li></ul></li><li><span><a href="#Online-training-(unregularized,-fixed-N)" data-toc-modified-id="Online-training-(unregularized,-fixed-N)-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Online training (unregularized, fixed N)</a></span><ul class="toc-item"><li><span><a href="#Params" data-toc-modified-id="Params-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Params</a></span></li><li><span><a href="#Create-test-data" data-toc-modified-id="Create-test-data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Create test data</a></span></li><li><span><a href="#Create-model" data-toc-modified-id="Create-model-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Create model</a></span></li><li><span><a href="#Compile-model" data-toc-modified-id="Compile-model-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Compile model</a></span></li><li><span><a href="#Manage-checkpoints" data-toc-modified-id="Manage-checkpoints-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Manage checkpoints</a></span></li><li><span><a href="#Train-network" data-toc-modified-id="Train-network-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Train network</a></span></li><li><span><a href="#Validate-evidential-network" data-toc-modified-id="Validate-evidential-network-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Validate evidential network</a></span><ul class="toc-item"><li><span><a href="#Posterior-probabilities" data-toc-modified-id="Posterior-probabilities-1.7.1"><span class="toc-item-num">1.7.1&nbsp;&nbsp;</span>Posterior probabilities</a></span></li><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-1.7.2"><span class="toc-item-num">1.7.2&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#Accuracy" data-toc-modified-id="Accuracy-1.7.3"><span class="toc-item-num">1.7.3&nbsp;&nbsp;</span>Accuracy</a></span></li></ul></li></ul></li><li><span><a href="#Online-training-(unregularized,-variable-N)" data-toc-modified-id="Online-training-(unregularized,-variable-N)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Online training (unregularized, variable N)</a></span><ul class="toc-item"><li><span><a href="#Params" data-toc-modified-id="Params-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Params</a></span></li><li><span><a href="#Create-test-data" data-toc-modified-id="Create-test-data-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Create test data</a></span></li><li><span><a href="#Create-model" data-toc-modified-id="Create-model-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Create model</a></span></li><li><span><a href="#Compile-model" data-toc-modified-id="Compile-model-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Compile model</a></span></li><li><span><a href="#Manage-checkpoints" data-toc-modified-id="Manage-checkpoints-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Manage checkpoints</a></span></li><li><span><a href="#Train-network" data-toc-modified-id="Train-network-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Train network</a></span></li><li><span><a href="#Validate" data-toc-modified-id="Validate-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Validate</a></span><ul class="toc-item"><li><span><a href="#Posterior-probabilities" data-toc-modified-id="Posterior-probabilities-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span>Posterior probabilities</a></span></li><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-2.7.2"><span class="toc-item-num">2.7.2&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#Accuracy-over-all-N" data-toc-modified-id="Accuracy-over-all-N-2.7.3"><span class="toc-item-num">2.7.3&nbsp;&nbsp;</span>Accuracy over all N</a></span></li><li><span><a href="#Min-accuracy" data-toc-modified-id="Min-accuracy-2.7.4"><span class="toc-item-num">2.7.4&nbsp;&nbsp;</span>Min accuracy</a></span></li></ul></li></ul></li><li><span><a href="#Online-training-(regularized,-fixed-N)" data-toc-modified-id="Online-training-(regularized,-fixed-N)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Online training (regularized, fixed N)</a></span><ul class="toc-item"><li><span><a href="#Params" data-toc-modified-id="Params-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Params</a></span></li><li><span><a href="#Create-model" data-toc-modified-id="Create-model-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Create model</a></span></li><li><span><a href="#Compile-model" data-toc-modified-id="Compile-model-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Compile model</a></span></li><li><span><a href="#Manage-checkpoints" data-toc-modified-id="Manage-checkpoints-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Manage checkpoints</a></span></li><li><span><a href="#Train-network" data-toc-modified-id="Train-network-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Train network</a></span></li><li><span><a href="#Validate-performance" data-toc-modified-id="Validate-performance-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Validate performance</a></span><ul class="toc-item"><li><span><a href="#Posterior-probs" data-toc-modified-id="Posterior-probs-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Posterior probs</a></span></li><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-3.6.2"><span class="toc-item-num">3.6.2&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#Accuracy" data-toc-modified-id="Accuracy-3.6.3"><span class="toc-item-num">3.6.3&nbsp;&nbsp;</span>Accuracy</a></span></li></ul></li></ul></li><li><span><a href="#Online-training-(regularized,-variable-N)" data-toc-modified-id="Online-training-(regularized,-variable-N)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Online training (regularized, variable N)</a></span><ul class="toc-item"><li><span><a href="#Params" data-toc-modified-id="Params-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Params</a></span></li><li><span><a href="#Compile-model" data-toc-modified-id="Compile-model-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Compile model</a></span></li><li><span><a href="#Manage-checkpoints" data-toc-modified-id="Manage-checkpoints-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Manage checkpoints</a></span></li><li><span><a href="#Train-network" data-toc-modified-id="Train-network-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Train network</a></span></li><li><span><a href="#Validate-performance|" data-toc-modified-id="Validate-performance|-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Validate performance|</a></span><ul class="toc-item"><li><span><a href="#Posterior-probabilities-max-N" data-toc-modified-id="Posterior-probabilities-max-N-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Posterior probabilities max N</a></span></li><li><span><a href="#Posterior-probabilities-min-N" data-toc-modified-id="Posterior-probabilities-min-N-4.5.2"><span class="toc-item-num">4.5.2&nbsp;&nbsp;</span>Posterior probabilities min N</a></span></li><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-4.5.3"><span class="toc-item-num">4.5.3&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#Min-accuracy" data-toc-modified-id="Min-accuracy-4.5.4"><span class="toc-item-num">4.5.4&nbsp;&nbsp;</span>Min accuracy</a></span></li><li><span><a href="#Accuracy-over-all-N" data-toc-modified-id="Accuracy-over-all-N-4.5.5"><span class="toc-item-num">4.5.5&nbsp;&nbsp;</span>Accuracy over all N</a></span></li></ul></li></ul></li><li><span><a href="#Compare-all-models" data-toc-modified-id="Compare-all-models-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Compare all models</a></span></li></ul></div>

# %%
import tensorflow as tf
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
import tensorflow.contrib.eager as tfe
from functools import partial
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import matplotlib.tri as tri
from scipy import stats
from scipy.special import gamma as gamma_fun
import scipy.special as spec
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as tqdm
import numpy as np


from deep_bayes.models import DeepEvidentialModel
from deep_bayes.settings import INVARIANT_DEFAULTS
from deep_bayes.training import train_online
from deep_bayes.losses import bayes_risk, regularized_bayes_risk
from deep_bayes.viz import plot_dirichlet_samples, plot_confusion_matrix
from deep_bayes.diagnostics import accuracy

# %%
# %load_ext autoreload
# %autoreload 2

# %%
tf.enable_eager_execution()

# %%
# %matplotlib inline

# %% [markdown]
# # Generative model specifications

# %% [markdown]
# ## Model prior
# <p>Defines the prior probabilities over models $p(\boldsymbol{m})$.</p>

# %%
def model_prior(batch_size, n_models, p_vals=None):
    """
    Samples from the models' prior batch size times and converts to one-hot.
    Assumes equal model priors.
    ----------
    
    Arguments:
    batch_size : int  -- the number of samples to draw from the prior
    n_models   : int  -- the number of generative models in queston
    ----------
    
    Returns:
    m_true : np.ndarray of shape (batch_size, theta_dim) -- the samples batch of parameters
    """
    
    # Equal priors, if nothign specified
    if p_vals is None:
        p_vals = [1/n_models] * n_models
    m_idx = np.random.choice(n_models, size=batch_size, p=p_vals).astype(np.int32)
    return m_idx

# %% [markdown]
# ## Model parameters priors
# <p>Defines how parameters are generated given a model $p(\boldsymbol{\theta}|\boldsymbol{m})$.</p>

# %%
def exponential_prior(**args):
    """
    Samples from the prior of the first model.
    ----------
    
    Arguments:
    ----------
    
    Output:
    theta : np.ndarray of shape (1, theta_dim) -- the samples of parameters
    """
    
    # Just as a toy example, sample from 2-D unit Gaussian
    theta = 1. / np.random.exponential(scale=1.)
    return theta


def lognormal_prior(**args):
    """
    Samples from the prior of the second model.
    ----------
    
    Arguments:
    ----------
    
    Output:
    theta : np.ndarray of shape (1, theta_dim) -- the samples of parameters
    """
    
    # Just as a toy example, sample from 2-D Gaussian with mean 1
    theta = np.random.normal(loc=0., scale=1.)
    return theta


def gamma_prior(**args):
    """
    Samples from the prior of the third model.
    ----------
    
    Arguments:
    ----------
    
    Output:
    theta : np.ndarray of shape (1, theta_dim) -- the samples of parameters
    """
    
    # Just as a toy example, sample from 2-D unit Gaussian with mean 2
    theta = np.random.exponential(scale=1.)
    return theta

# %% [markdown]
# ## Generative models
# <p>Defines how the data are generated, that is, $\boldsymbol{x}_{1:N} \sim p(\boldsymbol{x}|boldsymbol{\theta},\boldsymbol{m}).$

# %%
def exponential_model(scale, n_obs, **args):
    """
    Runs the forward model once, i.e., generates a sample from p(x|theta, m).
    ----------
    
    Arguments:
    params : np.ndarray of shape (theta_dim, ) -- the data generating parameters
    n_obs  : int -- the numebr of observations to draw from p(x|theta)
    ----------
    
    Output:
    x      : np.ndarray of shape (n_obs, x_dim)
    """
    
    x = np.random.exponential(scale=scale, size=(n_obs, 1))
    return x


def lognormal_model(mean, n_obs, **args):
    """
    Runs the forward model once, i.e., generates a sample from p(x|theta, m).
    ----------
    
    Arguments:
    params : np.ndarray of shape (theta_dim, ) -- the data generating parameters
    n_obs  : int -- the numebr of observations to draw from p(x|theta)
    ----------
    
    Output:
    x      : np.ndarray of shape (n_obs, x_dim)
    """
    
    x = np.random.lognormal(mean=mean, sigma=1., size=(n_obs, 1))
    return x


def gamma_model(scale, n_obs, **args):
    """
    Runs the forward model once, i.e., generates a sample from p(x|theta, m).
    ----------
    
    Arguments:
    params : np.ndarray of shape (theta_dim, ) -- the data generating parameters
    n_obs  : int -- the numebr of observations to draw from p(x|theta)
    ----------
    
    Output:
    x      : np.ndarray of shape (n_obs, x_dim)
    """
    
    x = np.random.gamma(shape=2., scale=scale, size=(n_obs, 1))
    return x

# %% [markdown]
# ## Data generator
# <p>Define the algorithm:</p>
# 1. <strong>for</strong> $i = 1,...,B$<br>
# 2. &emsp;$\boldsymbol{m}^{(i)} \sim p(\boldsymbol{m})$<br>
# 3. &emsp;$\boldsymbol{\theta}^{(i)} \sim p(\boldsymbol{\theta}|\boldsymbol{m}^{(i)})$<br>
# 4. &emsp;$\boldsymbol{x}_{1:N}^{(i)} \sim p(\boldsymbol{x}|\boldsymbol{\theta}^{(i)},\boldsymbol{m}^{(i)})$

# %%
def data_generator(batch_size, model_prior, param_priors, forward_models, 
                   n_obs=None, n_obs_min=100, n_obs_max=500, to_tensor=True, **args):
    """
    Runs the forward model 'batch_size' times by first sampling fromt the prior
    theta ~ p(theta) and running x ~ p(x|theta).
    ----------
    
    Arguments:
    batch_size     : int -- the number of samples to draw from the prior
    model_prior    : callable -- the prior which returns a sample of model indices
    param_priors   : list of callables -- a list with model prior samplers
    forward_models : list of generative models g(theta) -- a list of generatibve models
    n_obs          : int -- the numebr of observations to draw from p(x|theta)
    n_obs_min      : int -- used when n_obs is None, draws n_obs ~ U(n_obs_min, n_obs_max)
    n_obs_max      : int -- used when n_obs is None, draws n_obs ~ U(n_obs_min, n_obs_max)
    to_tensor      : boolean -- converts theta and x to tensors if True
    ----------
    
    Output:
    m     : tf.Tensor or np.ndarray of shape (batch_size, n_models) - the one-hot encoded version of the models
    theta : tf.Tensor or np.ndarray of shape (batch_size, theta_dim) - the data gen parameters 
    x     : tf.Tensor of np.ndarray of shape (batch_size, n_obs, x_dim)  - the generated data
    """
    
    # Sample from model prior
    # m_indices is an np.int32 array of model indices  
    n_models = len(forward_models)
    m_indices = model_prior(batch_size, n_models)
    
    # Sample N, if not specified
    if n_obs is None:
        n_obs = np.random.randint(low=n_obs_min, high=n_obs_max+1)
    
    # For each model index, sample from prior and run generative model.
    x = []
    theta = []
    for m_idx in m_indices:
        
        # Draw from model prior theta ~ p(theta|
        theta_m = param_priors[m_idx]()
        
        # Generate data from x = g_m(theta) <=> x ~ p(x|theta,m)
        x_m = forward_models[m_idx](theta_m, n_obs)
        
        # Store data and params
        x.append(x_m)
        theta.append(theta_m)
    
    # One-hot encode model indices
    m = to_categorical(m_indices, num_classes=n_models)
    
    # Convert to tensor, if specified 
    if to_tensor:
        theta = tf.convert_to_tensor(theta, dtype=tf.float32)
        x = tf.convert_to_tensor(x, dtype=tf.float32)
        m = tf.convert_to_tensor(m, dtype=tf.float32)
    return {'m': m, 'x': x}

# %% [markdown]
# # Online training (unregularized, fixed N)

# %% [markdown]
# ## Params

# %%
#--- Training hyperparameters ---#
ckpt_file = "toy_model_selection_fixed"
batch_size = 128
epochs = 10
iterations_per_epoch = 1000
n_obs = 20
n_test = 500


#--- Optimizer hyperparameters ---#
starter_learning_rate = 0.0005
global_step = tfe.Variable(0, dtype=tf.int32)
decay_steps = 1000
decay_rate = .99
learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step, 
                                           decay_steps, decay_rate, staircase=True)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)


#--- Generative model hyperparameters ---#
model_names = ['Expon', 'Lognorm', 'Gamma']


param_priors = [exponential_prior, lognormal_prior, gamma_prior]

forward_models = [exponential_model, lognormal_model, gamma_model]

data_gen = partial(data_generator, 
                   model_prior=model_prior, 
                   param_priors=param_priors,
                   forward_models=forward_models,
                   n_obs=n_obs)

# %% [markdown]
# ## Create test data

# %%
# %%time
test_data_min = data_gen(n_test)
# Out:
# Wall time: 21.8 ms

# %% [markdown]
# ## Create model

# %%
model_unreg_fixed = DeepEvidentialModel(INVARIANT_DEFAULTS, n_models=len(model_names), inv_xdim=False)

# %% [markdown]
# ## Compile model
# <p>In other words, run and plot performance of untrained networks.</p>

# %%
plot_dirichlet_samples(model_unreg_fixed, 
                       x_test=test_data_min['x'][:25], 
                       m_test=test_data_min['m'][:25], 
                       model_names=model_names,
                       figsize=(12, 8))

# %% [markdown]
# ## Manage checkpoints

# %%
checkpoint = tf.train.Checkpoint(step=global_step, optimizer=optimizer, net=model_unreg_fixed)
manager = tf.train.CheckpointManager(checkpoint, './checkpoints/{}'.format(ckpt_file), max_to_keep=2)
checkpoint.restore(manager.latest_checkpoint)
if manager.latest_checkpoint:
    print("Restored from {}".format(manager.latest_checkpoint))
else:
    print("Initializing from scratch.")
# Out:
# Initializing from scratch.

# %% [markdown]
# ## Train network

# %%
# %%time
for ep in range(1, epochs+1):
    with tqdm(total=iterations_per_epoch, desc='Training epoch {}'.format(ep)) as p_bar:
        losses = train_online(model=model_unreg_fixed, 
                              optimizer=optimizer, 
                              data_gen=data_gen, 
                              loss_fun=bayes_risk, 
                              iterations=iterations_per_epoch,
                              batch_size=batch_size,
                              p_bar=p_bar,
                              global_step=global_step,
                              method='evidence')
        
        # Plot stuff
        plot_dirichlet_samples(model_unreg_fixed, 
                       x_test=test_data_min['x'][:25], 
                       m_test=test_data_min['m'][:25], 
                       model_names=model_names,
                       figsize=(12, 8))
        plot_confusion_matrix(model_unreg_fixed, test_data_min['x'], test_data_min['m'], model_names)

        # Store checkpoint
        manager.save()
# Out:
# ...
# Wall time: 21min 57s

# %% [markdown]
# ## Validate evidential network

# %% [markdown]
# ### Posterior probabilities

# %%
plot_dirichlet_samples(model_unreg_fixed, 
                       x_test=test_data_min['x'][:25], 
                       m_test=test_data_min['m'][:25], 
                       model_names=model_names,
                       figsize=(12, 8))

# %% [markdown]
# ### Confusion matrix

# %%
plot_confusion_matrix(model_unreg_fixed, test_data_min['x'], test_data_min['m'], model_names, normalize=True)

# %% [markdown]
# ### Accuracy

# %%
m_pred = model_unreg_fixed(test_data_min['x'])['m_probs']
print(accuracy(test_data_min['m'], m_pred))
# Out:
# 0.752

# %% [markdown]
# # Online training (unregularized, variable N)

# %% [markdown]
# ## Params

# %%
#--- Training hyperparameters ---#
ckpt_file = "toy_model_selection_var"
batch_size = 128
epochs = 10
iterations_per_epoch = 1000
n_test = 500
n_obs_min = 20
n_obs_max = 500


#--- Optimizer hyperparameters ---#
starter_learning_rate = 0.0005
global_step = tfe.Variable(0, dtype=tf.int32)
decay_steps = 1000
decay_rate = .99
learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step, 
                                           decay_steps, decay_rate, staircase=True)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)


#--- Generative model hyperparameters ---#
model_names = ['Expon', 'Lognorm', 'Gamma']


param_priors = [exponential_prior, lognormal_prior, gamma_prior]
forward_models = [exponential_model, lognormal_model, gamma_model]

data_gen = partial(data_generator, 
                   model_prior=model_prior, 
                   param_priors=param_priors,
                   forward_models=forward_models,
                   n_obs_min=n_obs_min,
                   n_obs_max=n_obs_max)

# %% [markdown]
# ## Create test data

# %%
# %%time
test_data_max = data_gen(n_test, n_obs=n_obs_max)
# Out:
# Wall time: 224 ms

# %% [markdown]
# ## Create model

# %%
model_unreg_var = DeepEvidentialModel(INVARIANT_DEFAULTS, n_models=len(model_names), inv_xdim=False)

# %% [markdown]
# ## Compile model

# %%
plot_dirichlet_samples(model_unreg_var, 
                       x_test=test_data_max['x'][:25], 
                       m_test=test_data_max['m'][:25], 
                       model_names=model_names,
                       figsize=(12, 8))

# %% [markdown]
# ## Manage checkpoints

# %%
checkpoint = tf.train.Checkpoint(step=global_step, optimizer=optimizer, net=model_unreg_var)
manager = tf.train.CheckpointManager(checkpoint, './checkpoints/{}'.format(ckpt_file), max_to_keep=2)
checkpoint.restore(manager.latest_checkpoint)
if manager.latest_checkpoint:
    print("Restored from {}".format(manager.latest_checkpoint))
else:
    print("Initializing from scratch.")

# %% [markdown]
# ## Train network

# %%
# %%time
for ep in range(1, epochs+1):
    with tqdm(total=iterations_per_epoch, desc='Training epoch {}'.format(ep)) as p_bar:
        losses = train_online(model=model_unreg_var, 
                              optimizer=optimizer, 
                              data_gen=data_gen, 
                              loss_fun=bayes_risk, 
                              iterations=iterations_per_epoch,
                              batch_size=batch_size,
                              p_bar=p_bar,
                              global_step=global_step,
                              method='evidence')
        
        # Plot stuff
        plot_dirichlet_samples(model_unreg_var, 
                       x_test=test_data_max['x'][:25], 
                       m_test=test_data_max['m'][:25], 
                       model_names=model_names,
                       figsize=(12, 8))
        plot_confusion_matrix(model_unreg_var, test_data_max['x'], test_data_max['m'], model_names)

        # Store checkpoint
        manager.save()

# %% [markdown]
# ## Validate

# %% [markdown]
# ### Posterior probabilities

# %%
plot_dirichlet_samples(model_unreg_var, 
                       x_test=test_data_max['x'][:25], 
                       m_test=test_data_max['m'][:25], 
                       model_names=model_names,
                       figsize=(12, 8))

# %% [markdown]
# ### Confusion matrix

# %%
plot_confusion_matrix(model_unreg_var, test_data_max['x'], test_data_max['m'], model_names, normalize=True)

# %% [markdown]
# ### Accuracy over all N

# %%
accs = []
for n in range(n_obs_min, n_obs_max+1):
    
    # Create dataset
    test_data = data_gen(n_test, n_obs=n)
    m_pred = model_unreg_var(test_data['x'])['m_probs']
    acc = accuracy(test_data['m'], m_pred)
    accs.append(acc)

# %%
plt.plot(np.arange(n_obs_min, n_obs_max+1), accs)
plt.ylabel('Accuracy')
plt.xlabel('N')
# Out:
# Text(0.5, 0, 'N')

# %% [markdown]
# ### Min accuracy

# %%
m_pred = model_unreg_var(test_data_min['x'])['m_probs']
print(accuracy(test_data_min['m'], m_pred))

# %% [markdown]
# # Online training (regularized, fixed N)
# Uses the same test data as the fixed unregularized model

# %% [markdown]
# ## Params

# %%
#--- Training hyperparameters ---#
ckpt_file = "toy_model_selection_fixed_reg"
batch_size = 128
epochs = 10
iterations_per_epoch = 1000
n_test = 500
n_obs = 20
annealing_step = 5000


#--- Optimizer hyperparameters ---#
starter_learning_rate = 0.0005
global_step = tfe.Variable(0, dtype=tf.int32)
decay_steps = 1000
decay_rate = .99
learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step, 
                                           decay_steps, decay_rate, staircase=True)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)


#--- Generative model hyperparameters ---#
model_names = ['Expon', 'Lognorm', 'Gamma']
param_priors = [exponential_prior, lognormal_prior, gamma_prior]
forward_models = [exponential_model, lognormal_model, gamma_model]

data_gen = partial(data_generator, 
                   model_prior=model_prior, 
                   param_priors=param_priors,
                   forward_models=forward_models,
                   n_obs=n_obs)

# --- Loss --- #
risk = partial(regularized_bayes_risk, global_step=global_step, annealing_step=annealing_step)

# %% [markdown]
# ## Create model

# %%
model_reg_fixed = DeepEvidentialModel(INVARIANT_DEFAULTS, n_models=len(model_names), inv_xdim=False)

# %% [markdown]
# ## Compile model

# %%
plot_dirichlet_samples(model_reg_fixed, 
                       x_test=test_data_min['x'][:25], 
                       m_test=test_data_min['m'][:25], 
                       model_names=model_names,
                       figsize=(12, 8))

# %% [markdown]
# ## Manage checkpoints

# %%
checkpoint = tf.train.Checkpoint(step=global_step, optimizer=optimizer, net=model_reg_fixed)
manager = tf.train.CheckpointManager(checkpoint, './checkpoints/{}'.format(ckpt_file), max_to_keep=2)
checkpoint.restore(manager.latest_checkpoint)
if manager.latest_checkpoint:
    print("Restored from {}".format(manager.latest_checkpoint))
else:
    print("Initializing from scratch.")
# Out:
# Initializing from scratch.

# %% [markdown]
# ## Train network

# %%
# %%time
for ep in range(1, epochs+1):
    with tqdm(total=iterations_per_epoch, desc='Training epoch {}'.format(ep)) as p_bar:
        losses = train_online(model=model_reg_fixed, 
                              optimizer=optimizer, 
                              data_gen=data_gen, 
                              loss_fun=risk, 
                              iterations=iterations_per_epoch,
                              batch_size=batch_size,
                              p_bar=p_bar,
                              global_step=global_step,
                              method='evidence')
        
        # Plot stuff
        plot_dirichlet_samples(model_reg_fixed, 
                       x_test=test_data_min['x'][:25], 
                       m_test=test_data_min['m'][:25], 
                       model_names=model_names,
                       figsize=(12, 8))
        plot_confusion_matrix(model_reg_fixed, test_data_min['x'], test_data_min['m'], model_names)

        # Store checkpoint
        manager.save()
# Out:
# ...
# WARNING:tensorflow:From D:\Anaconda3\envs\TensorFlowGpu\lib\site-packages\tensorflow\python\training\checkpoint_management.py:624: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# ...
# Wall time: 9min 43s

# %% [markdown]
# ## Validate performance

# %% [markdown]
# ### Posterior probs

# %%
plot_dirichlet_samples(model_reg_fixed, 
                       x_test=test_data_min['x'][:25], 
                       m_test=test_data_min['m'][:25], 
                       model_names=model_names,
                       figsize=(12, 8))

# %% [markdown]
# ### Confusion matrix

# %%
plot_confusion_matrix(model_reg_fixed, test_data_min['x'], test_data_min['m'], model_names, normalize=True)

# %% [markdown]
# ### Accuracy

# %%
m_pred = model_reg_fixed(test_data_min['x'])['m_probs']
print(accuracy(test_data_min['m'], m_pred))
# Out:
# 0.704

# %% [markdown]
# # Online training (regularized, variable N)
# Use the same test data as for the unregularized variable version

# %% [markdown]
# ## Params

# %%
#--- Training hyperparameters ---#
ckpt_file = "toy_model_selection_var_reg"
batch_size = 128
epochs = 10
iterations_per_epoch = 1000
n_test = 500
n_obs_min = 20
n_obs_max = 500
annealing_step = 5000


#--- Optimizer hyperparameters ---#
starter_learning_rate = 0.0005
global_step = tfe.Variable(0, dtype=tf.int32)
decay_steps = 1000
decay_rate = .99
learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step, 
                                           decay_steps, decay_rate, staircase=True)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)


#--- Generative model hyperparameters ---#
model_names = ['Expon', 'Lognorm', 'Gamma']


param_priors = [exponential_prior, lognormal_prior, gamma_prior]

forward_models = [exponential_model, lognormal_model, gamma_model]

data_gen = partial(data_generator, 
                   model_prior=model_prior, 
                   param_priors=param_priors,
                   forward_models=forward_models,
                   n_obs_min=n_obs_min,
                   n_obs_max=n_obs_max)

# --- Loss --- #
risk = partial(regularized_bayes_risk, global_step=global_step, annealing_step=annealing_step)

# %%
model_reg_var = DeepEvidentialModel(INVARIANT_DEFAULTS, n_models=len(model_names), inv_xdim=False)

# %% [markdown]
# ## Compile model

# %%
plot_dirichlet_samples(model_reg_var, 
                       x_test=test_data_max['x'][:25], 
                       m_test=test_data_max['m'][:25], 
                       model_names=model_names,
                       figsize=(12, 8))

# %% [markdown]
# ## Manage checkpoints

# %%
checkpoint = tf.train.Checkpoint(step=global_step, optimizer=optimizer, net=model_reg_var)
manager = tf.train.CheckpointManager(checkpoint, './checkpoints/{}'.format(ckpt_file), max_to_keep=2)
checkpoint.restore(manager.latest_checkpoint)
if manager.latest_checkpoint:
    print("Restored from {}".format(manager.latest_checkpoint))
else:
    print("Initializing from scratch.")
# Out:
# Initializing from scratch.

# %% [markdown]
# ## Train network

# %%
# %%time
for ep in range(1, epochs+1):
    with tqdm(total=iterations_per_epoch, desc='Training epoch {}'.format(ep)) as p_bar:
        losses = train_online(model=model_reg_var, 
                              optimizer=optimizer, 
                              data_gen=data_gen, 
                              loss_fun=risk, 
                              iterations=iterations_per_epoch,
                              batch_size=batch_size,
                              p_bar=p_bar,
                              global_step=global_step,
                              method='evidence')
        
        # Plot stuff
        plot_dirichlet_samples(model_reg_var, 
                       x_test=test_data_max['x'][:25], 
                       m_test=test_data_max['m'][:25], 
                       model_names=model_names,
                       figsize=(12, 8))
        plot_confusion_matrix(model_reg_var, test_data_max['x'], test_data_max['m'], model_names)

        # Store checkpoint
        manager.save()

# %% [markdown]
# ## Validate performance|

# %% [markdown]
# ### Posterior probabilities max N

# %%
plot_dirichlet_samples(model_reg_var, 
                       x_test=test_data_max['x'][:25], 
                       m_test=test_data_max['m'][:25], 
                       model_names=model_names,
                       figsize=(12, 8))

# %% [markdown]
# ### Posterior probabilities min N

# %%
plot_dirichlet_samples(model_reg_var, 
                       x_test=test_data_min['x'][:25], 
                       m_test=test_data_min['m'][:25], 
                       model_names=model_names,
                       figsize=(12, 8))

# %% [markdown]
# ### Confusion matrix

# %%
plot_confusion_matrix(model_reg_var, test_data_max['x'], test_data_max['m'], model_names, normalize=True)

# %%
plot_confusion_matrix(model_reg_var, test_data_min['x'], test_data_min['m'], model_names, normalize=True)

# %% [markdown]
# ### Min accuracy

# %%
m_pred = model_reg_var(test_data_min['x'])['m_probs']
print(accuracy(test_data_min['m'], m_pred))

# %% [markdown]
# ### Accuracy over all N

# %%
accs = []
for n in range(n_obs_min, n_obs_max+1):
    
    # Create dataset
    test_data = data_gen(n_test, n_obs=n)
    m_pred = model_reg_var(test_data['x'])['m_probs']
    acc = accuracy(test_data['m'], m_pred)
    accs.append(acc)

# %%
plt.plot(np.arange(n_obs_min, n_obs_max+1), accs)
plt.ylabel('Accuracy')
plt.xlabel('N')
# Out:
# Text(0.5, 0, 'N')

# %% [markdown]
# # Compare all models
