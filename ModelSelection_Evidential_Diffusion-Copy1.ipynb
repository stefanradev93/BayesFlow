# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
import tensorflow.contrib.eager as tfe
from functools import partial
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import matplotlib.tri as tri
from scipy import stats
from scipy.special import gamma as gamma_fun
import scipy.special as spec
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as tqdm
import numpy as np


from deep_bayes.diagnostics import accuracy
from deep_bayes.models import DeepEvidentialModel
from deep_bayes.settings import INVARIANT_DIFFUSION
from deep_bayes.training import train_online, train_offline
from deep_bayes.losses import bayes_risk, regularized_bayes_risk
from deep_bayes.viz import plot_dirichlet_samples, plot_confusion_matrix

from simulators.diffusion_lib import simulate_diffusion

# %%
tf.enable_eager_execution()

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %matplotlib inline

# %% [markdown]
# # Generative model specifications

# %% [markdown]
# ## Model prior
# <p>Defines the prior probabilities over models $p(\boldsymbol{m})$.</p>

# %%
def model_prior(batch_size, n_models, p_vals=None):
    """
    Samples from the models' prior batch size times and converts to one-hot.
    Assumes equal model priors.
    ----------
    
    Arguments:
    batch_size : int  -- the number of samples to draw from the prior
    n_models   : int  -- the number of generative models in queston
    ----------
    
    Returns:
    m_true : np.ndarray of shape (batch_size, theta_dim) -- the samples batch of parameters
    """
    
    # Equal priors, if nothign specified
    if p_vals is None:
        p_vals = [1/n_models] * n_models
    m_idx = np.random.choice(n_models, size=batch_size, p=p_vals).astype(np.int32)
    return m_idx

# %% [markdown]
# ## Model parameters priors
# <p>Defines how parameters are generated given a model $p(\boldsymbol{\theta}|\boldsymbol{m})$.</p>

# %%
def model1_params_prior(**args):
    """
    Samples from the prior of the simple diffusion model theta = (v, zr, a, ndt)
    ----------
    
    Arguments:
    ----------
    
    Output:
    theta : np.ndarray of shape (1, theta_dim) -- the samples of parameters
            or a dict with param key-values
    """
    
    # Just as a toy example, sample from 2-D unit Gaussian
    theta = {
        'drifts': np.random.uniform(low=-6.0, high=6.0, size=2),
        'a': np.random.uniform(low=0.6, high=3.0),
        'zr': np.random.uniform(low=0.3, high=0.7),
        'ndt': np.random.uniform(low=0.2, high=1.5),
        'alpha': np.random.uniform(low=1.0, high=2.0)
    }
    return thetazz


def model2_params_prior(**args):
    """
    Samples from the prior of the simple diffusion model theta = (v, zr, a, ndt, alpha)
    ----------
    
    Arguments:
    ----------
    
    Output:
    theta : np.ndarray of shape (1, theta_dim) -- the samples of parameters
            or a dict with param key-values
    """
    
    # Just as a toy example, sample from 2-D unit Gaussian
    theta = {
        'drifts': np.random.uniform(low=-6.0, high=6.0, size=2),
        'a': np.random.uniform(low=0.6, high=3.0),
        'zr': np.random.uniform(low=0.3, high=0.7),
        'ndt': np.random.uniform(low=0.2, high=1.5),
        'alpha': np.random.uniform(low=1.0, high=2.0)
    }
    return theta


def model3_params_prior(**args):
    """
    Samples from the prior of the simple diffusion model theta = (v, zr, szr, a, ndt, alpha)
    ----------
    
    Arguments:
    ----------
    
    Output:
    theta : np.ndarray of shape (1, theta_dim) -- the samples of parameters
            or a dict with param key-values
    """
    
    # Just as a toy example, sample from 2-D unit Gaussian
    theta = {
        'drifts': np.random.uniform(low=-6.0, high=6.0, size=2),
        'a': np.random.uniform(low=0.6, high=3.0),
        'zr': np.random.uniform(low=0.3, high=0.7),
        'szr': np.random.uniform(low=0.0, high=0.6),
        'ndt': np.random.uniform(low=0.2, high=1.5),
        'alpha': np.random.uniform(low=1.0, high=2.0)
    }
    return theta


def model4_params_prior(**args):
    """
    Samples from the prior of the simple diffusion model theta = (v, sv, zr, szr, a, ndt, alpha)
    ----------
    
    Arguments:
    ----------
    
    Output:
    theta : np.ndarray of shape (1, theta_dim) -- the samples of parameters
            or a dict with param key-values
    """
    
    # Just as a toy example, sample from 2-D unit Gaussian
    theta = {
        'drifts': np.random.uniform(low=-6.0, high=6.0, size=2),
        'a': np.random.uniform(low=0.6, high=3.0),
        'sv': np.random.uniform(low=0.0, high=2.0),
        'zr': np.random.uniform(low=0.3, high=0.7),
        'szr': np.random.uniform(low=0.0, high=0.6),
        'ndt': np.random.uniform(low=0.2, high=1.5),
        'alpha': np.random.uniform(low=1.0, high=2.0)
    }
    return theta


def model5_params_prior(**args):
    """
    Samples from the prior of the simple diffusion model theta = (v, sv, zr, szr, a, ndt, sndt, alpha)
    ----------
    
    Arguments:
    ----------
    
    Output:
    theta : np.ndarray of shape (1, theta_dim) -- the samples of parameters
            or a dict with param key-values
    """
    
    # Just as a toy example, sample from 2-D unit Gaussian
    theta = {
        'drifts': np.random.uniform(low=-6.0, high=6.0, size=2),
        'a': np.random.uniform(low=0.6, high=3.0),
        'sv': np.random.uniform(low=0.0, high=2.0),
        'zr': np.random.uniform(low=0.3, high=0.7),
        'szr': np.random.uniform(low=0.0, high=0.6),
        'ndt': np.random.uniform(low=0.2, high=1.5),
        'sndt': np.random.uniform(low=0.0, high=0.4),
#         'alpha': np.random.uniform(low=1.0, high=2.0)
    }
    return theta

# %% [markdown]
# ## Generative models
# <p>Defines how the data are generated, that is, $\boldsymbol{x}_{1:N} \sim p(\boldsymbol{x}|boldsymbol{\theta},\boldsymbol{m}).$

# %%
def forward_model1(params, n_obs, **args):
    """
    Runs the forward model once, i.e., generates a sample from p(x|theta, m).
    ----------
    
    Arguments:
    params : dict with key value pairs -- the data generating parameters
    n_obs  : int -- the numebr of observations to draw from p(x|theta)
    ----------
    
    Output:
    x      : np.ndarray of shape (n_obs, x_dim)
    """
    
    # Again, toy
    x = simulate_diffusion(**params, n_points=n_obs)
    return x


def forward_model2(params, n_obs, **args):
    """
    Runs the forward model once, i.e., generates a sample from p(x|theta, m).
    ----------
    
    Arguments:
    params : dict with key value pairs -- the data generating parameters
    n_obs  : int -- the numebr of observations to draw from p(x|theta)
    ----------
    
    Output:
    x      : np.ndarray of shape (n_obs, x_dim)
    """
    
    # Again, toy
    x = simulate_diffusion(**params)
    return x


def forward_model3(params, n_obs, **args):
    """
    Runs the forward model once, i.e., generates a sample from p(x|theta, m).
    ----------
    
    Arguments:
    params : dict with key value pairs -- the data generating parameters
    n_obs  : int -- the numebr of observations to draw from p(x|theta)
    ----------
    
    Output:
    x      : np.ndarray of shape (n_obs, x_dim)
    """
    
    # Again, toy
    x = simulate_diffusion(**params)
    return x


def forward_model4(params, n_obs, **args):
    """
    Runs the forward model once, i.e., generates a sample from p(x|theta, m).
    ----------
    
    Arguments:
    params : dict with key value pairs -- the data generating parameters
    n_obs  : int -- the numebr of observations to draw from p(x|theta)
    ----------
    
    Output:
    x      : np.ndarray of shape (n_obs, x_dim)
    """
    
    # Again, toy
    x = simulate_diffusion(**params)
    return x


def forward_model5(params, n_obs, **args):
    """
    Runs the forward model once, i.e., generates a sample from p(x|theta, m).
    ----------
    
    Arguments:
    params : dict with key value pairs -- the data generating parameters
    n_obs  : int -- the numebr of observations to draw from p(x|theta)
    ----------
    
    Output:
    x      : np.ndarray of shape (n_obs, x_dim)
    """
    
    # Again, toy
    x = simulate_diffusion(**params, n_points=n_obs) 
    return x

# %% [markdown]
# ## Data generator
# <p>Define the algorithm:</p>
# 1. <strong>for</strong> $i = 1,...,B$<br>
# 2. &emsp;$\boldsymbol{m}^{(i)} \sim p(\boldsymbol{m})$<br>
# 3. &emsp;$\boldsymbol{\theta}^{(i)} \sim p(\boldsymbol{\theta}|\boldsymbol{m}^{(i)})$<br>
# 4. &emsp;$\boldsymbol{x}_{1:N}^{(i)} \sim p(\boldsymbol{x}|\boldsymbol{\theta}^{(i)},\boldsymbol{m}^{(i)})$

# %%
def data_generator(batch_size, model_prior, param_priors, forward_models, 
                   n_obs=100, n_obs_min=100, n_obs_max=500, to_tensor=True, **args):
    """
    Runs the forward model 'batch_size' times by first sampling fromt the prior
    theta ~ p(theta) and running x ~ p(x|theta).
    ----------
    
    Arguments:
    batch_size     : int -- the number of samples to draw from the prior
    model_prior    : callable -- the prior which returns a sample of model indices
    param_priors   : list of callables -- a list with model prior samplers
    forward_models : list of generative models g(theta) -- a list of generatibve models
    n_obs          : int -- the numebr of observations to draw from p(x|theta)
    n_obs_min      : int -- used when n_obs is None, draws n_obs ~ U(n_obs_min, n_obs_max)
    n_obs_max      : int -- used when n_obs is None, draws n_obs ~ U(n_obs_min, n_obs_max)
    to_tensor      : boolean -- converts theta and x to tensors if True
    ----------
    
    Output:
    m     : tf.Tensor or np.ndarray of shape (batch_size, n_models) - the one-hot encoded version of the models
    x     : tf.Tensor of np.ndarray of shape (batch_size, n_obs, x_dim)  - the generated data
    """
    
    # Sample from model prior
    # m_indices is an np.int32 array of model indices  
    n_models = len(forward_models)
    m_indices = model_prior(batch_size, n_models)
    
    # Sample N, if not specified
    if n_obs is None:
        n_obs = np.random.randint(low=n_obs_min, high=n_obs_max+1)
    
    # For each model index, sample from prior and run generative model.
    x = []
    theta = []
    for m_idx in m_indices:
        
        # Draw from model prior theta ~ p(theta|
        theta_m = param_priors[m_idx]()
        
        # Generate data from x = g_m(theta) <=> x ~ p(x|theta,m)
        x_m = forward_models[m_idx](theta_m, n_obs=n_obs)
        
        # Store data and params
        x.append(x_m)
    
    # One-hot encode model indices
    m = to_categorical(m_indices, num_classes=n_models)
    
    # Convert to tensor, if specified 
    if to_tensor:
        x = tf.convert_to_tensor(x, dtype=tf.float32)
        m = tf.convert_to_tensor(m, dtype=tf.float32)
    return {'m': m, 'x': x}

# %% [markdown]
# # Training hyperparameters

# %%
#--- Training hyperparameters ---#
ckpt_file = "model_selection_diffusion"
batch_size = 64
epochs = 500
iterations_per_epoch = 100
n_obs = 250
n_test = 500
annealing_step = 20000


#--- Optimizer hyperparameters ---#
starter_learning_rate = 0.001
global_step = tfe.Variable(0, dtype=tf.int32)
decay_steps = 1000
decay_rate = .99
learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step, 
                                           decay_steps, decay_rate, staircase=True)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)


#--- Generative model hyperparameters ---#
# model_names = ['Diff1', 'Diff2', 'Diff3', 'Diff4', 'Diff5']
model_names = ['Diff1', 'Diff5']
param_priors = [model1_params_prior, 
#                 model2_params_prior, 
#                 model3_params_prior,
#                 model4_params_prior, 
                model5_params_prior]

forward_models = [forward_model1, 
#                   forward_model2, 
#                   forward_model3,
#                   forward_model4, 
                  forward_model5]


data_gen = partial(data_generator, 
                   model_prior=model_prior, 
                   param_priors=param_priors,
                   forward_models=forward_models,
                   n_obs=n_obs)


risk = partial(regularized_bayes_risk, global_step=global_step, annealing_step=annealing_step, max_lambda=0.5)

# %% [markdown]
# ## Create test data

# %%
# %%time
test_data = data_gen(n_test, to_tensor=True)
# Out:
# Wall time: 15.6 s

# %% [markdown]
# ## Create model

# %%
model = DeepEvidentialModel(INVARIANT_DIFFUSION, n_models=len(model_names), inv_xdim=False)

# %% [markdown]
# ## Compile model
# <p>In other words, run and plot performance of untrained networks.</p>

# %%
plot_dirichlet_samples(model, 
                       x_test=test_data['x'][:25], 
                       m_test=test_data['m'][:25], 
                       model_names=model_names,
                       figsize=(12, 8))

# %%
plot_confusion_matrix(model, test_data['x'], test_data['m'], model_names, normalize=True)

# %% [markdown]
# ## Manage checkpoints

# %%
checkpoint = tf.train.Checkpoint(step=global_step, optimizer=optimizer, net=model)
manager = tf.train.CheckpointManager(checkpoint, './checkpoints/{}'.format(ckpt_file), max_to_keep=2)
checkpoint.restore(manager.latest_checkpoint)
if manager.latest_checkpoint:
    print("Restored from {}".format(manager.latest_checkpoint))
else:
    print("Initializing from scratch.")
# Out:
# Initializing from scratch.

# %% [markdown]
# # Train network online

# %%
# %%time
for ep in range(1, epochs+1):
    with tqdm(total=iterations_per_epoch, desc='Training epoch {}'.format(ep)) as p_bar:
        losses = train_online(model=model, 
                              optimizer=optimizer, 
                              data_gen=data_gen, 
                              loss_fun=risk, 
                              iterations=iterations_per_epoch,
                              batch_size=batch_size,
                              p_bar=p_bar,
                              global_step=global_step,
                              method='evidence')
        
        # Plot stuff
        plot_confusion_matrix(model, test_data['x'], test_data['m'], model_names)
        plot_dirichlet_samples(model, 
                       x_test=test_data['x'][:25], 
                       m_test=test_data['m'][:25], 
                       model_names=model_names,
                       figsize=(12, 8))

        # Store checkpoint
#         manager.save()
# Out:
# HBox(children=(IntProgress(value=0, description='Training epoch 1', style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Training epoch 2', style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Training epoch 3', style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Training epoch 4', style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Training epoch 5', style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Training epoch 6', style=ProgressStyle(description_width='ini…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\Desktop\Projects\BayesFlow\deep_bayes\training.py in train_online(model, optimizer, data_gen, loss_fun, iterations, batch_size, p_bar, clip_value, clip_method, global_step, n_smooth, method)
#      55
#      56             # Generate inputs for the network
# ---> 57             batch = data_gen(batch_size)
#      58
#      59             if method == 'flow':
#
# <ipython-input-54-7ece031deafd> in data_generator(batch_size, model_prior, param_priors, forward_models, n_obs, n_obs_min, n_obs_max, to_tensor, **args)
#      50     # Convert to tensor, if specified
#      51     if to_tensor:
# ---> 52         x = tf.convert_to_tensor(x, dtype=tf.float32)
#      53         m = tf.convert_to_tensor(m, dtype=tf.float32)
#      54     return {'m': m, 'x': x}
#
# D:\Anaconda3\envs\TensorFlowGpu\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, preferred_dtype)
#    1037     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#    1038   """
# -> 1039   return convert_to_tensor_v2(value, dtype, preferred_dtype, name)
#    1040
#    1041
#
# D:\Anaconda3\envs\TensorFlowGpu\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1095       name=name,
#    1096       preferred_dtype=dtype_hint,
# -> 1097       as_ref=False)
#    1098
#    1099
#
# D:\Anaconda3\envs\TensorFlowGpu\lib\site-packages\tensorflow\python\framework\ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, ctx, accept_symbolic_tensors)
#    1173
#    1174     if ret is None:
# -> 1175       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1176
#    1177     if ret is NotImplemented:
#
# D:\Anaconda3\envs\TensorFlowGpu\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     302                                          as_ref=False):
#     303   _ = as_ref
# --> 304   return constant(v, dtype=dtype, name=name)
#     305
#     306
#
# D:\Anaconda3\envs\TensorFlowGpu\lib\site-packages\tensorflow\python\framework\constant_op.py in constant(value, dtype, shape, name)
#     243   """
#     244   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 245                         allow_broadcast=True)
#     246
#     247
#
# D:\Anaconda3\envs\TensorFlowGpu\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     251   ctx = context.context()
#     252   if ctx.executing_eagerly():
# --> 253     t = convert_to_eager_tensor(value, ctx, dtype)
#     254     if shape is None:
#     255       return t
#
# KeyboardInterrupt:

# %% [markdown]
# ## Validate evidential network

# %%
# plot_dirichlet_samples(model, 
#                    x_test=test_data['x'][:25], 
#                    m_test=test_data['m'][:25], 
#                    model_names=model_names,
#                    figsize=(12, 8))

# %%
plot_confusion_matrix(model, test_data['x'], test_data['m'], model_names)

# %% [markdown]
# # Train network offline

# %% [markdown]
# ## Params

# %%
#--- Training hyperparameters ---#
ckpt_file = "model_selection_diffusion"
batch_size = 64
epochs = 50
n_obs = 500
n_test = 500
model_names = ['Diff', 'Levy']
annealing_step = 20000


#--- Optimizer hyperparameters ---#
starter_learning_rate = 0.0005
global_step = tfe.Variable(0, dtype=tf.int32)
decay_steps = 1000
decay_rate = .99
learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step, 
                                           decay_steps, decay_rate, staircase=True)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)

# --- Dataset ---#
X = np.load('sim_data/X.npy')
m = np.load('sim_data/Y.npy')
X_test = tf.convert_to_tensor(np.load('sim_data/X_test.npy'))
m_test = tf.convert_to_tensor(np.load('sim_data/Y_test.npy'))
dataset = tf.data.Dataset.from_tensor_slices((X, m)).shuffle(X.shape[0]).batch(batch_size)

# %%
risk = partial(regularized_bayes_risk, global_step=global_step, annealing_step=annealing_step, max_lambda=0.5)

# %%
model = DeepEvidentialModel(INVARIANT_DIFFUSION, n_models=len(model_names))

# %%
checkpoint = tf.train.Checkpoint(step=global_step, optimizer=optimizer, net=model)
manager = tf.train.CheckpointManager(checkpoint, './checkpoints/{}'.format(ckpt_file), max_to_keep=2)
checkpoint.restore(manager.latest_checkpoint)
if manager.latest_checkpoint:
    print("Restored from {}".format(manager.latest_checkpoint))
else:
    print("Initializing from scratch.")
# Out:
# Restored from ./checkpoints/model_selection_diffusion\ckpt-31

# %%
# %%time
# for ep in range(1, 20+1):
#     with tqdm(total=X.shape[0] // batch_size, desc='Training epoch {}'.format(ep)) as p_bar:
#         train_offline(model=model, 
#                       optimizer=optimizer, 
#                       dataset=dataset, 
#                       loss_fun=risk, 
#                       batch_size=batch_size, 
#                       p_bar=p_bar, 
#                       clip_method='value', 
#                       global_step=global_step, 
#                       method='evidential')
        
#         plot_confusion_matrix(model, X_test, m_test, model_names)
#         plot_dirichlet_samples(model, 
#                        x_test=X_test[:25], 
#                        m_test=m_test[:25], 
#                        model_names=model_names,
#                        figsize=(12, 8))
#         m_pred = model(X_test)['m_probs']
#         print(accuracy(m_test, m_pred))
        
# #         manager.save()
# Out:
# HBox(children=(IntProgress(value=0, description='Training epoch 1', max=937, style=ProgressStyle(description_w…
# 0.803
# HBox(children=(IntProgress(value=0, description='Training epoch 2', max=937, style=ProgressStyle(description_w…
# 0.842
# HBox(children=(IntProgress(value=0, description='Training epoch 3', max=937, style=ProgressStyle(description_w…
# 0.858
# HBox(children=(IntProgress(value=0, description='Training epoch 4', max=937, style=ProgressStyle(description_w…
# 0.823
# HBox(children=(IntProgress(value=0, description='Training epoch 5', max=937, style=ProgressStyle(description_w…
# 0.845
# HBox(children=(IntProgress(value=0, description='Training epoch 6', max=937, style=ProgressStyle(description_w…
# 0.846
# HBox(children=(IntProgress(value=0, description='Training epoch 7', max=937, style=ProgressStyle(description_w…
# 0.851
# HBox(children=(IntProgress(value=0, description='Training epoch 8', max=937, style=ProgressStyle(description_w…
# 0.787
# HBox(children=(IntProgress(value=0, description='Training epoch 9', max=937, style=ProgressStyle(description_w…
# 0.848
# HBox(children=(IntProgress(value=0, description='Training epoch 10', max=937, style=ProgressStyle(description_…
# 0.854
# HBox(children=(IntProgress(value=0, description='Training epoch 11', max=937, style=ProgressStyle(description_…
# 0.768
# HBox(children=(IntProgress(value=0, description='Training epoch 12', max=937, style=ProgressStyle(description_…
# 0.859
# HBox(children=(IntProgress(value=0, description='Training epoch 13', max=937, style=ProgressStyle(description_…
# 0.88
# HBox(children=(IntProgress(value=0, description='Training epoch 14', max=937, style=ProgressStyle(description_…
# 0.859
# HBox(children=(IntProgress(value=0, description='Training epoch 15', max=937, style=ProgressStyle(description_…
# 0.877
# HBox(children=(IntProgress(value=0, description='Training epoch 16', max=937, style=ProgressStyle(description_…
# 0.838
# HBox(children=(IntProgress(value=0, description='Training epoch 17', max=937, style=ProgressStyle(description_…
# 0.881
# HBox(children=(IntProgress(value=0, description='Training epoch 18', max=937, style=ProgressStyle(description_…
# 0.858
# HBox(children=(IntProgress(value=0, description='Training epoch 19', max=937, style=ProgressStyle(description_…
# 0.829
# HBox(children=(IntProgress(value=0, description='Training epoch 20', max=937, style=ProgressStyle(description_…
# 0.877
#
# Wall time: 44min 28s
# Parser   : 103 ms

# %% [markdown]
# ## Validate

# %%
plot_dirichlet_samples(model, 
                   x_test=X_test[:25], 
                   m_test=m_test[:25], 
                   model_names=model_names,
                   figsize=(12, 8))

# %%
plot_confusion_matrix(model, X_test, m_test, model_names, normalize=True)
# Out:
# WARNING:tensorflow:From D:\Anaconda3\envs\TensorFlowGpu\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1595: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
m_pred = model(X_test)['m_probs']
print(accuracy(m_test, m_pred))
# Out:
# 0.877

# %% [markdown]
# # Playground

# %%
def model1_params_prior(**args):
    """
    Samples from the prior of the simple diffusion model theta = (v, zr, a, ndt)
    ----------
    
    Arguments:
    ----------
    
    Output:
    theta : np.ndarray of shape (1, theta_dim) -- the samples of parameters
            or a dict with param key-values
    """
    
    # Just as a toy example, sample from 2-D unit Gaussian
    theta = {
        'drifts': np.array([np.random.uniform(low=0.0, high=6.0),np.random.uniform(low=-6.0, high=0.0)]),
        'a': np.random.uniform(low=0.6, high=3.0),
        'zr': np.random.uniform(low=0.3, high=0.7),
        'ndt': np.random.uniform(low=0.3, high=1.0),
        'alpha': np.random.uniform(low=1.0, high=2.0)
    }
    return theta

def model5_params_prior(**args):
    """
    Samples from the prior of the simple diffusion model theta = (v, sv, zr, szr, a, ndt, sndt, alpha)
    ----------
    
    Arguments:
    ----------
    
    Output:
    theta : np.ndarray of shape (1, theta_dim) -- the samples of parameters
            or a dict with param key-values
    """
    
    # Just as a toy example, sample from 2-D unit Gaussian
    theta = {
        'drifts': np.array([np.random.uniform(low=0.0, high=6.0),np.random.uniform(low=-6.0, high=0.0)]),
        'a': np.random.uniform(low=0.6, high=3.0),
        'sv': np.random.uniform(low=0.0, high=2.0),
        'zr': np.random.uniform(low=0.3, high=0.7),
        'szr': np.random.uniform(low=0.0, high=0.6),
        'ndt': np.random.uniform(low=0.3, high=1.0),
        'sndt': np.random.uniform(low=0.0, high=0.2),
#         'alpha': np.random.uniform(low=1.0, high=2.0)
    }
    return theta



def model1_params_eqprior(**args):
    """
    Samples from the prior of the simple diffusion model theta = (v, zr, a, ndt)
    ----------
    
    Arguments:
    ----------
    
    Output:
    theta : np.ndarray of shape (1, theta_dim) -- the samples of parameters
            or a dict with param key-values
    """
    
    # Just as a toy example, sample from 2-D unit Gaussian
    theta = {
        'drifts': np.array([np.random.uniform(low=0.0, high=6.0),np.random.uniform(low=-6.0, high=0.0)]),
        'a': np.random.uniform(low=0.6, high=3.0),
        'zr': np.random.uniform(low=0.3, high=0.7),
        'ndt': np.random.uniform(low=0.3, high=1.0),
#         'alpha': np.random.uniform(low=1.0, high=2.0)
    }
    return theta

def model5_params_eqprior(**args):
    """
    Samples from the prior of the simple diffusion model theta = (v, sv, zr, szr, a, ndt, sndt, alpha)
    ----------
    
    Arguments:
    ----------
    
    Output:
    theta : np.ndarray of shape (1, theta_dim) -- the samples of parameters
            or a dict with param key-values
    """
    
    # Just as a toy example, sample from 2-D unit Gaussian
    theta = {
        'drifts': np.array([np.random.uniform(low=0.0, high=6.0),np.random.uniform(low=-6.0, high=0.0)]),
        'a': np.random.uniform(low=0.6, high=3.0),
#         'sv': np.random.uniform(low=0.0, high=2.0),
        'zr': np.random.uniform(low=0.3, high=0.7),
#         'szr': np.random.uniform(low=0.0, high=0.6),
        'ndt': np.random.uniform(low=0.3, high=1.0),
#         'sndt': np.random.uniform(low=0.0, high=0.2),
#         'alpha': np.random.uniform(low=1.0, high=2.0)
    }
    return theta

# %%
def forward_model1(params, n_obs, **args):
    """
    Runs the forward model once, i.e., generates a sample from p(x|theta, m).
    ----------
    
    Arguments:
    params : dict with key value pairs -- the data generating parameters
    n_obs  : int -- the numebr of observations to draw from p(x|theta)
    ----------
    
    Output:
    x      : np.ndarray of shape (n_obs, x_dim)
    """
    
    # Again, toy
    x = simulate_diffusion(**params, n_points=n_obs)
    return x


def forward_model5(params, n_obs, **args):
    """
    Runs the forward model once, i.e., generates a sample from p(x|theta, m).
    ----------
    
    Arguments:
    params : dict with key value pairs -- the data generating parameters
    n_obs  : int -- the numebr of observations to draw from p(x|theta)
    ----------
    
    Output:
    x      : np.ndarray of shape (n_obs, x_dim)
    """
    
    # Again, toy
    x = simulate_diffusion(**params, n_points=n_obs) 
    return x

# %%
param_priors = [model5_params_prior, model1_params_prior, 
#                 model2_params_prior, 
#                 model3_params_prior,
#                 model4_params_prior, 
                ]

param_priors_eq = [model5_params_eqprior, model1_params_eqprior]

forward_models = [forward_model5, forward_model1, 
#                   forward_model2, 
#                   forward_model3,
#                   forward_model4, 
                  ]


data_gen = partial(data_generator, 
                   model_prior=model_prior, 
                   param_priors=param_priors,
                   forward_models=forward_models,
                   n_obs=n_obs)

data_gen_eq = partial(data_generator, 
                   model_prior=model_prior, 
                   param_priors=param_priors_eq,
                   forward_models=forward_models,
                   n_obs=n_obs)

# %%
test_data = data_gen(1000)
test_data_eq = data_gen_eq(1000)

# %%
plot_confusion_matrix(model, test_data['x'], test_data['m'], model_names, normalize=True)

# %%
plot_confusion_matrix(model, test_data_eq['x'], test_data_eq['m'], model_names, normalize=True)

# %%
plot_dirichlet_samples(model, 
                       x_test=test_data_eq['x'][:25], 
                       m_test=test_data_eq['m'][:25], 
                       model_names=model_names,
                       figsize=(12, 8))
